# %% [markdown]
# <a href="https://colab.research.google.com/github/LeeLupton/WebHosting/blob/main/Final_Exam_(e_commerce_inventory_management).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Important Pre-Work Instructions**
#
# Before beginning your assignments, please take the following critical step:
#
# For security and academic integrity, you MUST **disable the AI assistant** in Google Colab:
# 1. Go to Settings
# 2. Navigate to AI Assistant options and **disable** all of the following:
#   - Show AI-power inline completions
#   - Consented to use generative AI features
#   - Hide generative AI features
#
# This ensures your work reflects your own learning and understanding.Unauthorized AI assistance during assignments is considered academic misconduct.
#
# If you have questions about the assignment, please consult your instructor directly.
#
# ---

# %% [markdown]
# ## **Saving Your Colab Notebook to Google Drive**
#
# Google Colab makes it easy to save your notebooks directly to your Google Drive, so you can access them from anywhere and keep them organized. Here's how:
#
# **1. Connect to Google Drive:**
#
# * **Click on the "Files" icon** in the left sidebar of your Colab notebook.
# * **Click on "Mount Drive"**. This will prompt you to authorize Colab to access your Google Drive.
# * **Follow the on-screen instructions** to grant permission. Once you've done this, your Google Drive will be connected to your Colab notebook.
#
# **2. Save a Copy in Drive:**
#
# * **Click on "File" in the menu bar.**
# * **Select "Save a copy in Drive".** This will create a copy of your current notebook and save it in your Google Drive.
#     * By default, it will be saved in the "Colab Notebooks" folder in your Drive.
#
# **3. (Optional) Choose a Different Location:**
#
# * **If you want to save the notebook in a different folder,** you can click on the folder icon next to the filename in the "Save a copy in Drive" dialog box.
# * **Navigate to the folder** where you want to save the notebook and click "Select".
#
# **4. (Optional) Rename the Notebook:**
#
# * **You can also rename the notebook** before saving it by changing the text in the filename field.
#
# **5. Click "Save".**
#
# That's it! Your Colab notebook is now safely saved in your Google Drive. You can access it anytime by going to your Drive and opening the "Colab Notebooks" folder (or the folder you chose).
#
# **Important Notes:**
#
# * **Saving a copy:** The "Save a copy in Drive" option creates a new copy of your notebook in Drive. Any changes you make to the original notebook in Colab will not be reflected in the saved copy, and vice versa.
# * **Automatic saving:** Colab also has an autosave feature, but it's always a good idea to manually save your work regularly to avoid losing any changes.
#
# ---

# %% [markdown]
# # **Final Exam**
#
# Welcome to the final exam for our Python programming course! This exam is designed to assess your ability to apply the concepts and skills you've learned throughout the course to solve a practical problem. You'll be challenged to design and implement an e-commerce order management system using object-oriented programming principles.
#
# This is your opportunity to demonstrate your mastery of Python programming, including:
#
# * Defining classes and creating objects
# * Implementing methods and attributes
# * Working with lists and dictionaries
# * Using control flow statements (if-else, loops)
# * Handling errors with try-except blocks
# * Organizing and documenting your code effectively
#
# Take your time, read the instructions carefully, and show us what you've learned! Good luck!
#
# **Learning Objectives:**
#
# * **Object-Oriented Programming (OOP):** Apply OOP principles to design and implement a system using classes and objects.
# * **Class Design:** Design and implement classes with appropriate attributes and methods.
# * **Inheritance:** (Optional) Consider using inheritance if there are opportunities for code reuse and creating a class hierarchy.
# * **Encapsulation:** Utilize encapsulation to protect data integrity and control access to attributes.
# * **List Manipulation:** Work with lists to store and manage collections of objects.
# * **Data Management:** Demonstrate the ability to manage and manipulate data within objects and lists.
# * **Problem-Solving:** Apply Python programming skills to solve a practical e-commerce order management problem.
# * **Code Organization:** Write well-organized and readable code with clear comments and documentation.
#
# **Instructions:**
#
# 1. **Save a cpopy of this notebook and rename as instructed.**
# 2. **Name the notebook:** "[Your Name] - Final Exam".
# 3. **Complete the following problem:**
#
# ## **Problem:  E-commerce Order Management System**
#
# **Scenario:** You are developing an order management system for an e-commerce platform. You need to be able to represent products, customers, and orders, and perform operations such as adding products, creating orders, calculating totals, and displaying order information.
#
# **Task:**
#
# Design and implement a Python program using classes and methods to manage e-commerce orders. The program should include the following features:
#
# 1. **Product Class:**
#    - Create a `Product` class with attributes for product ID, name, price, and quantity in stock.
#    - Include methods to:
#      - Display product information.
#      - Update product quantity.
#
# 2. **Customer Class:**
#    - Create a `Customer` class with attributes for customer ID, name, and email address.
#    - Include a method to display customer information.
#
# 3. **Order Class:**
#    - Create an `Order` class with attributes for order ID, customer, order date, and a list of order items.
#    - Include methods to:
#      - Add a product to the order.
#      - Remove a product from the order.
#      - Calculate the total cost of the order.
#      - Display the order details, including customer information, order date, items ordered, and total cost.
#
# 4. **Order Management:**
#    - Create a list to store `Product` objects.
#    - Create a list to store `Customer` objects.
#    - Create a list to store `Order` objects.
#    - Implement functions or methods to:
#      - Add new products to the product list.
#      - Add new customers to the customer list.
#      - Create new orders, adding products and assigning customers.
#      - Display all orders.
#      - Display all products.
#      - Display all customers.
#
# ## **Additional Features:**
#
# 1. **Inventory Management:**
#    - Add functionality to check if there is enough inventory to fulfill an order. If not, prevent the order from being created and display an appropriate message.
#    - Update product quantities automatically when orders are created.
#
# 2. **Order History:**
#    - Add a method to the `Customer` class to display their order history (all orders associated with that customer).
#
# 3. **Search:**
#    - Implement a search function to find products by name or ID.
#
# ##**Test Cases:**
#
# 1. **Insufficient Inventory:**
#    - Create a product with a quantity of 5.
#    - Try to create an order for 10 units of that product.
#    - Verify that the order is not created and an appropriate message is displayed.
#
# 2. **Order History:**
#    - Create a customer and two orders associated with that customer.
#    - Call the order history method for that customer.
#    - Verify that the correct orders are displayed.
#
# 3. **Search:**
#    - Add several products to the product list.
#    - Search for a product by its name.
#    - Search for a product by its ID.
#    - Verify that the correct products are found in each case.
#
# **Instructions:**
#
# 1. **Design the Classes:** Plan the attributes and methods for each class (`Product`, `Customer`, `Order`).
# 2. **Implement the Classes:** Write the Python code for each class, including their constructors and methods.
# 3. **Create Objects:** Create instances of the classes with relevant data.
# 4. **Implement Order Management:** Write functions or methods to manage products, customers, and orders.
# 5. **Implement Additional Features:** Add the inventory management, order history, and search functionalities.
# 6. **Test the Program:** Thoroughly test the program with various scenarios, including the provided test cases, to ensure it functions correctly.
# 7. **Submit your Google Colab notebook** with the completed code and clear outputs demonstrating the functionality of your program.

# %%
# Your code here

import datetime # you need this library to handle dates

class Product:
    """
    Represents a product in the e-commerce system.
    """

    def __init__(self, product_id, name, price, quantity):
        """
        Initializes Product with ID, name, price, and quantity.
        """
        pass

# continue with your code here

# %% [markdown]
# ## Test cases
#
# You will be evaluated based on the following test cases. Make sure you run these test cases and ensure they work as expected.
#
# ```python
# # Test Cases
#
# # Create some products
# product1 = Product(product_id="P001", name="Laptop", price=1200, quantity=10)
# add_product(product1)
# product2 = Product(product_id="P002", name="Mouse", price=25, quantity=50)
# add_product(product2)
#
# # Create a customer
# customer1 = Customer(customer_id="C001", name="Alice Smith", email="alice@example.com")
# add_customer(customer1)
#
# # Create an order
# order1 = create_order(order_id="O001", customer=customer1, order_date="2024-12-25")
# order1.add_product(product=product1, quantity=2)  # Add 2 laptops to the order
# order1.add_product(product=product2, quantity=1)  # Add 1 mouse to the order
#
# # Test Case 1: Insufficient Inventory
# order2 = create_order(order_id="O002", customer=customer1, order_date="2024-12-26")
# order2.add_product(product=product1, quantity=10)  # Try to order 10 laptops (only 8 left)
#
# # Test Case 2: Order History
# order3 = create_order(order_id="O003", customer=customer1, order_date="2024-12-27")
# order3.add_product(product=product2, quantity=5)  # Add 5 mice to the order
# customer1.display_order_history()
#
# # Test Case 3: Search
# search_results = search_product("Laptop")
# for product in search_results:
#     product.display_product_info()
#
# search_results = search_product("P002")
# for product in search_results:
#     product.display_product_info()
#
# # Display all orders, products, and customers
# display_all_orders()
# display_all_products()
# display_all_customers()
#
# ```

# %% [markdown]
# The expected output of the test cases are
#
# ```
# Added 2 Laptop(s) to the order.
# Added 1 Mouse(s) to the order.
# Insufficient stock for Laptop.
# Added 5 Mouse(s) to the order.
# Order history for Alice Smith:
#
# Product ID: P001
# Name: Laptop
# Price: $1200
# Quantity in stock: 8
# --------------------
# Product ID: P001
# Name: Laptop
# Price: $1200
# Quantity in stock: 8
# --------------------
# Product ID: P002
# Name: Mouse
# Price: $25
# Quantity in stock: 44
# --------------------
# Product ID: P002
# Name: Mouse
# Price: $25
# Quantity in stock: 44
# --------------------
# All Orders:
# Order ID: O001
# Customer: Alice Smith
# Order Date: 2024-12-25
# Items:
# 	- Laptop x 2 = $2400
# 	- Mouse x 1 = $25
# Total cost: $2425
# --------------------
# Order ID: O002
# Customer: Alice Smith
# Order Date: 2024-12-26
# Items:
# Total cost: $0
# --------------------
# Order ID: O003
# Customer: Alice Smith
# Order Date: 2024-12-27
# Items:
# 	- Mouse x 5 = $125
# Total cost: $125
# --------------------
# Order ID: O001
# Customer: Alice Smith
# Order Date: 2024-12-25
# Items:
# 	- Laptop x 2 = $2400
# 	- Mouse x 1 = $25
# Total cost: $2425
# --------------------
# Order ID: O002
# Customer: Alice Smith
# Order Date: 2024-12-26
# Items:
# Total cost: $0
# --------------------
# Order ID: O003
# Customer: Alice Smith
# Order Date: 2024-12-27
# Items:
# 	- Mouse x 5 = $125
# Total cost: $125
# --------------------
# All Products:
# Product ID: P001
# Name: Laptop
# Price: $1200
# Quantity in stock: 8
# --------------------
# Product ID: P002
# Name: Mouse
# Price: $25
# Quantity in stock: 44
# --------------------
# Product ID: P001
# Name: Laptop
# Price: $1200
# Quantity in stock: 8
# --------------------
# Product ID: P002
# Name: Mouse
# Price: $25
# Quantity in stock: 44
# --------------------
# All Customers:
# Customer ID: C001
# Name: Alice Smith
# Email: alice@example.com
# --------------------
# Customer ID: C001
# Name: Alice Smith
# Email: alice@example.com
# --------------------
# ```
